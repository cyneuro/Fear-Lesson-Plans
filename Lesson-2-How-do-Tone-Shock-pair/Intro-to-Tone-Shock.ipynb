# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cyneuro/Fear-Lesson-Plans/blob/master/Lesson-2-How-do-Tone-Shock-pair/Intro-to-Tone-Shock.ipynb)

# %% [markdown]
# # What is Tone and Shock
# ## Below is a more in depth 1-cell model of the amygdala. Here we will see how the timing of the tone and shock is imperative for us to learn. Remember, the tone is what is learned like the bell with Pavlov while the shock is equivalent to the food. For a refresher on the Pavlov experiment and how it works, watch the video below.

# %%
#@title Run cell to load video

from IPython.display import YouTubeVideo
YouTubeVideo('jd7Jdug5SRc')

# %% [markdown]
# ## The model is a PN cell with tone and shock inputs as shown below:

# %% [markdown]
# ![tone+shock neuron.png](data:image/png;base64,...)

# %% [markdown]
# ## This model has different parameters available compared to last time. The frequency of how often the tone and shock are free to change as well as when the shock starts. The orange lines on the plots show when the first shock occurs and the last one is just after the last one ends. Any spikes that occur outside the orange lines are caused by just tone.
#
# ---
# ## CHALLENGE - Adjust the 3 given parameters to ensure the cell spikes with only tone, i.e. spike after the second orange line. There must be no spikes before the first orange line.
#
# ### Hints:
# *   #### The video on Pavlov's dog has some keen insights about the timing of the two stimuli.

# %%
#@title download files
import os
RunningInCOLAB = 'google.colab' in str(get_ipython())  # checks to see if we are in google colab
if RunningInCOLAB:                                     # installs packages and repo if in colab
    # !pip install ipywidgets &> /dev/null
    # !pip install neuron &> /dev/null

    # !git clone https://github.com/cyneuro/Fear-Lesson-Plans &> /dev/null
    # %cd Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair

if(os.path.exists('x86_64')==False):
    os.system('nrnivmodl modfiles')
# Out:
# /Users/gregglickert/opt/anaconda3/envs/bmtk/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# /usr/bin/xcrun
# /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair
# Mod files: "modfiles/modfiles/AMPA_NMDA_LTP.mod" "modfiles/modfiles/AMPA_NMDA_STP.mod" "modfiles/modfiles/Gfluct_new_exc.mod" "modfiles/modfiles/Gfluct_new_inh.mod" "modfiles/modfiles/cadyn.mod" "modfiles/modfiles/capool.mod" "modfiles/modfiles/currentclamp.mod" "modfiles/modfiles/h.mod" "modfiles/modfiles/im.mod" "modfiles/modfiles/kadist.mod" "modfiles/modfiles/kaprox.mod" "modfiles/modfiles/kdrca1.mod" "modfiles/modfiles/leak.mod" "modfiles/modfiles/na3.mod" "modfiles/modfiles/nap.mod" "modfiles/modfiles/pyr2pyr.mod" "modfiles/modfiles/sahp.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../modfiles/AMPA_NMDA_LTP.mod
#  -> NMODL ../modfiles/AMPA_NMDA_STP.mod
#  -> NMODL ../modfiles/Gfluct_new_exc.mod
#  -> NMODL ../modfiles/Gfluct_new_inh.mod
#  -> NMODL ../modfiles/cadyn.mod
#  -> NMODL ../modfiles/capool.mod
#  -> NMODL ../modfiles/currentclamp.mod
#  -> NMODL ../modfiles/h.mod
#  -> NMODL ../modfiles/im.mod
#  -> NMODL ../modfiles/kadist.mod
#  -> NMODL ../modfiles/kaprox.mod
#  -> NMODL ../modfiles/kdrca1.mod
#  -> NMODL ../modfiles/leak.mod
#  -> NMODL ../modfiles/na3.mod
#  -> NMODL ../modfiles/nap.mod
#  -> NMODL ../modfiles/pyr2pyr.mod
#  -> NMODL ../modfiles/sahp.mod
#  -> Compiling AMPA_NMDA_LTP.c
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
#  -> Compiling AMPA_NMDA_STP.c
#  -> Compiling Gfluct_new_exc.c
#  -> Compiling Gfluct_new_inh.c
# Translating AMPA_NMDA_STP.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/AMPA_NMDA_STP.c
# Translating AMPA_NMDA_LTP.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/AMPA_NMDA_LTP.c
# Translating Gfluct_new_exc.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/Gfluct_new_exc.c
# Notice: This mechanism cannot be used with CVODE
# Thread Safe
# Thread Safe
# Thread Safe
# Translating cadyn.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/cadyn.c
# Translating Gfluct_new_inh.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/Gfluct_new_inh.c
# Thread Safe
# Notice: This mechanism cannot be used with CVODE
# Thread Safe
# Translating capool.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/capool.c
# WARNING: xx (a STATE) is assigned a value in a DERIVATIVE block.
#  Multistep integrators (such as Runge) may not work correctly.
# Thread Safe
# Translating currentclamp.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/currentclamp.c
# Translating h.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/h.c
# Thread Safe
# Thread Safe
# Translating im.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/im.c
# Thread Safe
# Translating kadist.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/kadist.c
# Translating kaprox.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/kaprox.c
# Thread Safe
# Thread Safe
# Translating kdrca1.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/kdrca1.c
# Thread Safe
# Translating leak.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/leak.c
# Translating na3.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/na3.c
# Thread Safe
# Thread Safe
# Translating nap.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/nap.c
# Thread Safe
# Translating pyr2pyr.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/pyr2pyr.c
# Translating sahp.mod into /Users/gregglickert/Documents/GitHub/Fear-Lesson-Plans/Lesson-2-How-do-Tone-Shock-pair/x86_64/sahp.c
# Warning: dt undefined. (declared within VERBATIM?)
# Thread Safe
# Thread Safe
# AMPA_NMDA_LTP.c:42:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# AMPA_NMDA_LTP.c:771:32: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#   if (_tsav > t){ extern char* hoc_object_name(); hoc_execerror(hoc_object_name(_pnt->ob), ":Event arrived out of order. Must call ParallelContext.set_maxstep AFTER assigning minimum NetCon.delay");}
#                                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:46:14: note: conflicting prototype is here
# extern char* hoc_object_name(Object*);
#              ^
# Gfluct_new_exc.cAMPA_NMDA_STP.c:43:42::1818: :warning:  a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]warning:
# a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#          extern double *getarg();                        ^
#
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h/Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h::15:1517: note: :expanded from macro 'getarg'
# 17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^#define getarg  hoc_getarg
#                 ^
#
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h/Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h::4949::16: note: 16conflicting prototype is here:
#  note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# extern double* getarg(int);
#                ^/Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:
# 17: note: /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.hexpanded from macro 'getarg':
# 15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
# #define getarg  hoc_getarg
#                 ^                ^
#
# AMPA_NMDA_STP.c:416:32: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#   if (_tsav > t){ extern char* hoc_object_name(); hoc_execerror(hoc_object_name(_pnt->ob), ":Event arrived out of order. Must call ParallelContext.set_maxstep AFTER assigning minimum NetCon.delay");}
#                                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:46:14: note: conflicting prototype is here
# extern char* hoc_object_name(Object*);
#              ^
# Gfluct_new_inh.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# 1 warning generated.
# 2 warnings generated.
# 1 warning generated.
# cadyn.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
#  -> Compiling cadyn.c
#  -> Compiling capool.c
#  -> Compiling currentclamp.c
#  -> Compiling h.c
#  -> Compiling im.c
#  -> Compiling kadist.c
#  -> Compiling kaprox.c
# 2 warnings generated.
# capool.c:42:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# currentclamp.c:41:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# h.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# im.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# kadist.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# kaprox.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# 1 warning generated.
#  -> Compiling kdrca1.c
#  -> Compiling leak.c
#  -> Compiling na3.c
#  -> Compiling nap.c
#  -> Compiling pyr2pyr.c
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# kdrca1.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# leak.c:41:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# na3.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# nap.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
#  -> Compiling sahp.c
#  => LINKING shared library ./libnrnmech.dylib
# pyr2pyr.c:42:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# pyr2pyr.c:611:32: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#   if (_tsav > t){ extern char* hoc_object_name(); hoc_execerror(hoc_object_name(_pnt->ob), ":Event arrived out of order. Must call ParallelContext.set_maxstep AFTER assigning minimum NetCon.delay");}
#                                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:46:14: note: conflicting prototype is here
# extern char* hoc_object_name(Object*);
#              ^
# sahp.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C2x, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#          extern double *getarg();
#                         ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# extern double* getarg(int);
#                ^
# /Users/gregglickert/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# #define getarg  hoc_getarg
#                 ^
# 1 warning generated.
# 2 warnings generated.
#  => LINKING executable ./special LDFLAGS are:
# Successfully created x86_64/special
# ld: warning: ignoring duplicate libraries: '-lnrnmech'

# %%
#@title Run cell to activate model
import numpy as np
from os.path import normpath, sep, join

import matplotlib.pyplot as plt
from matplotlib import gridspec
from neuron import h
from neuron.units import ms, mV
import ipywidgets as widgets
from ipywidgets import interactive_output,HBox,VBox,Label,Layout
from IPython.display import display
# %matplotlib inline
h.load_file('stdrun.hoc')

h.dt = 0.1 # time step (resolution) of the simulation in ms
h.tstop = 1700 # how long to run the simulation in ms
h.v_init= -65 # initial membrane potential in mV
h.load_file('PN_cells.hoc') # reads in template
cell = h.PN_C() #cell from template file


tone2pyr0 = h.pyr2pyr((cell.soma[0](0.5))) # makes a syn connected to soma
shock2pyr0 = h.pyr2pyr((cell.soma[0](0.5)))

def generate_spike_times(firing_rate,start_time, end_time):
    if firing_rate == 0:# in case shock is set to 0 fix divide by zero error
        firing_rate = 1
        start_time = 4000
        end_time = 5000
    interval = 1000.0 / firing_rate  # Interval between spikes in ms (1000 ms = 1 second)
    spike_times = []
    time = start_time
    while time <= end_time:
        spike_times.append(time)
        time += interval
    return spike_times


t = h.Vector()      # Vectors are used to record data in the simulation
Soma_v = h.Vector()

t.record(h._ref_t)                # derefences and records data
Soma_v.record(cell.soma[0](0.5)._ref_v)


def plot_variables(tone_freq,shock_start,shock_spike_times): # plots stuff

    fig = plt.figure(figsize=(15, 5),tight_layout=True)
    gs = gridspec.GridSpec(2, 1, width_ratios=[1],height_ratios=[1,1])

    ax0 = plt.subplot(gs[1,:])
    ax1 = plt.subplot(gs[0,:])

    ax0.plot(t, Soma_v)
    ax0.legend(['Soma Vm'])
    ax0.set_ylabel('Voltage (mV)')
    ax0.set_xlabel('Time (ms)')
    ax0.set_ylim(-80,50)
    #print(shock_spike_times)
    if(shock_spike_times[0] != 4000):
      ax0.axvline(x = shock_start, color = 'orange', linestyle = 'dashdot')
      ax0.axvline(x = shock_start+1000, color = 'orange', linestyle = 'dashdot')
    ax0.set_xlim(0,1800)

    ax1.set_ylabel('Inputs')
    ax1.set_xlabel("Time (ms)")

    if tone_freq == 0:  # in case tone is set to 0 fix divide by zero error
        tone = np.arange(3000,4000,1)
    else:
        tone = np.arange(100,1750,1000/tone_freq)
    tone_index = []
    for i in range(len(tone)):
        tone_index.append(1)
    shock_index = []
    for i in range(len(shock_spike_times)):
        shock_index.append(2)

    ax1.scatter(shock_spike_times,shock_index,label='Shock')
    ax1.scatter(tone,tone_index,label='Tone')
    if tone_freq == 0:
        major_ticks = np.arange(3000,4000,1)
    else:
        major_ticks = np.arange(100, 1750, 1000/tone_freq)
    y_ticks = np.arange(1,3,1)
    ax1.set_xticks(major_ticks)
    ax1.set_yticks(y_ticks)
    ax1.legend()
    n = 4  # Keeps every 4th tick label
    [l.set_visible(False) for (i,l) in enumerate(ax1.xaxis.get_ticklabels()) if i % n != 0]
    ax1.grid()
    ax1.set_xlim(0,1800)
    ax1.set_ylim(0.8,2.2)

    plt.show()

def activemodel(initW_tone, initW_shock,tone,shock,shock_start,thres1=0.26, thres2=0.31):
    weight_tone = initW_tone
    if (weight_tone == 0):
        weight_tone = 0.0000000001

    weight_shock = initW_shock
    if (weight_shock == 0):
        weight_shock = 0.00000000001

    tone_freq = tone
    shock_freq = shock

    tone2pyr0.initW = weight_tone
    tone2pyr0.threshold1 = thres1
    tone2pyr0.threshold2 = thres2
    shock2pyr0.threshold1 = 5
    shock2pyr0.threshold2 = 6
    tone2pyr0.Beta_nmda = 0.026
    #soma[i].diam = 30

    nstim_tone = h.NetStim(0.9) # makes spike trains
    if (tone_freq != 0):
        nstim_tone.interval=(1000/tone_freq) # ms (mean) time between spikes
        nstim_tone.start = 100               # ms (most likely) start time of first spike
    else:
        nstim_tone.interval=0
        nstim_tone.start = 10000            # way to make the tone freq 0 during stim time
    nstim_tone.number = 100                 # (average) number of spikes
    nstim_tone.noise = 0                    # range 0 to 1. Fractional randomness.
    nc_tone = h.NetCon(nstim_tone,tone2pyr0,0,0,1)    # connects tone to soma via tone2pyr syn

    shock2pyr0.initW = weight_shock
    firing_rate = shock_freq  # Firing rate in Hz
    start_time = shock_start  # Start time in ms
    end_time = shock_start+999  # End time in ms


    shock_spike_times = generate_spike_times(firing_rate,start_time,end_time)
    netcons = [h.NetCon(None, shock2pyr0) for _ in shock_spike_times]
#    Create a NEURON event to deliver the spikes
    h.cvode.active(1)  # Activate the CVODE solver

    h.finitialize(h.v_init * mV)  # runs sims

    for netcon, time in zip(netcons, shock_spike_times):
        netcon.event(time)

    h.continuerun(h.tstop * ms)
    plt.close('all')
    plot_variables(tone_freq,shock_start,shock_spike_times)

#change these values
initW_tone = 0.19
initW_shock = 8.3
thres1 = 0.26
thres2 = 0.31
#
diam = 30
tone_freq = 3
shock_freq = 5
shock_start = 250

w_reset = widgets.Button(description="Reset", disabled=False, button_style='info', tooltip='Reset parameters', icon='refresh')
w_solution = widgets.Button(description='Show Solution',icon='history',button_style='primary')
w_initW_tone = widgets.FloatSlider(value=initW_tone, min=0, max=20, step=0.1,layout=Layout(width='20%', height='15px'))
w_initW_shock = widgets.FloatSlider(value=initW_shock, min=0, max=20, step=0.1,layout=w_initW_tone.layout)
w_shock_start = widgets.FloatSlider(value=shock_start,min=100,max=500,step=1,layout=w_initW_tone.layout)
w_tone_f = widgets.IntSlider(value=tone_freq, min=0, max=15, step=1,layout=w_initW_tone.layout)
w_shock_f = widgets.IntSlider(value=shock_freq, min=0, max=15, step=1,layout=w_initW_tone.layout)
w_thres1 = widgets.FloatSlider(value=thres1, min=0.01, max=1, step=0.05,layout=w_initW_tone.layout)
w_thres2 = widgets.FloatSlider(value=thres2, min=0.01, max=1, step=0.05,layout=w_initW_tone.layout)

def reset_default(*args):
    #w_initW_tone.value = initW_tone
    #w_initW_shock.value = initW_shock
    #w_thres1.value = thres1
    #w_thres2.value = thres2
    w_tone_f.value = tone_freq
    w_shock_f.value = shock_freq
    w_shock_start.value = shock_start

w_reset.on_click(reset_default)

def show_solution(*args):
    w_tone_f.value = 15
    w_shock_f.value = 15
    w_shock_start.value = 100

w_solution.on_click(show_solution)


labels = ['Tone Freq','Shock Freq','Shock Start Time','Tone Weight','Shock Weight','Threshold1','Threshold2']
Labels = [Label(L) for L in labels]

ui = VBox([HBox([w_reset,w_solution]), HBox([Labels[0],w_tone_f,Labels[1], w_shock_f,Labels[2],w_shock_start])])
out = interactive_output(activemodel, {'initW_tone':w_initW_tone,'initW_shock':w_initW_shock,
                                       'tone':w_tone_f,'shock':w_shock_f,'shock_start':w_shock_start})

display(ui,out)
# Out:
# VBox(children=(HBox(children=(Button(button_style='info', description='Reset', icon='refresh', style=ButtonSty…
# Output()
